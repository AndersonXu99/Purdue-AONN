# %%
import numpy as np
from scipy.optimize import least_squares
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
from IPython.display import Image
import multiprocessing

# %% [markdown]
# ## COLD ATOM

# %%
Transparency_Omega_1 = None
Transparency_Omega_2 = None
Om_2_list_adapted = None

# Constants
epsilon_0 = 8.854e-12  # Vacuum permittivity (F/m)
hbar = 1.054e-34       # Reduced Planck's constant (J·s)
mu_13 = mu_23 = 2.5377e-29      # Dipole moment between states (|1> and |3>) and (|1> and |3>) (C·m)

Gamma3 = 2 * np.pi * 6e6   # (Hz)
Gamma31 = 5/9 * Gamma3   # Decay from level 3 to level 1 (Hz)
Gamma32 = Gamma23 = 4/9 * Gamma3   # Decay from level 3 to level 2 (Hz)
Gamma12 = Gamma21 = 0.05 * Gamma3    # Decay rates between levels 1 and 2 (Hz)
gamma13 = (Gamma3 + Gamma12)/2  # Decoherence rate between levels 1 and 3 (Hz)
gamma23 = (Gamma3 + Gamma21)/2  # Decoherence rate between levels 2 and 3 (Hz)
gamma12 = (Gamma12 + Gamma21)/2     # Decoherence rate between ground states (Hz)

w_1 = 2 * np.pi * 3e8 / 795e-9
k_0 = w_1 / 3e8
L = 0.1        # Length in meters
z = 0.00001    # Step size in meters

OD_0 = 10
N1 = OD_0 / ((4 * np.pi * mu_13**2 * L) / (Gamma3 * hbar * epsilon_0 * 795e-9))
N = 3.46e16
print("{:.2e}".format(N))
print("{:.2e}".format(N1))

# Backend function to calculate OD based on user input
def calculate_OD_1(Om_1=1.0, delta_1=0.0, delta_2=0.0):

    Om_2_list = 7 * Gamma3 + 0j
    Om_1_list = Om_1 * Gamma3 + 0j
    
    nz = int(L / z)  # Number of z steps
    z_array = np.arange(nz) * z  # Array of z values
    
    # Initialize arrays to store Rabi frequencies at each z step
    Om_2_vs_z = []
    Om_1_vs_z = []

    # Initialize arrays to store rho31 and rho32
    rho31_values = np.zeros((nz), dtype=complex)
    rho32_values = np.zeros((nz), dtype=complex)

    for i in range(nz):
        if i == nz/4 or i == nz/2 or i == 3*nz/4: 
            print(f"Processing z step {i}/{nz}")
        
        Om_2_actual = Om_2_list      # Convert to actual Omega_2 in MHz
        Om_1_actual = Om_1_list      # Convert Om_1 to MHz

        delta_1_actual = delta_1 * Gamma3
        delta_2_actual = delta_2 * Gamma3

        # Construct A and b as per Code2
        # Define the imaginary unit
        I = 1j

        # Construct the matrix A
        A = np.array([
            # Row 1
            [Gamma31 + Gamma12, 0, I*Om_1_actual/2, 0, Gamma31 - Gamma21, 0, -I*np.conjugate(Om_1_actual)/2, 0],
            # Row 2
            [0, gamma12 - I*(delta_2_actual - delta_1_actual), I*Om_2_actual/2, 0, 0, 0, 0, -I*np.conjugate(Om_1_actual)/2],
            # Row 3
            [I*np.conjugate(Om_1_actual), I*np.conjugate(Om_2_actual)/2, gamma13 + I*delta_1_actual, 0, I*np.conjugate(Om_1_actual)/2, 0, 0, 0],
            # Row 4
            [0, 0, 0, gamma12 + I*(delta_2_actual - delta_1_actual), 0, I*Om_1_actual/2, -I*np.conjugate(Om_2_actual)/2, 0],
            # Row 5
            [Gamma32 - Gamma12, 0, 0, 0, Gamma32 + Gamma21, I*Om_2_actual/2, 0, -I*np.conjugate(Om_2_actual)/2],
            # Row 6
            [I*np.conjugate(Om_2_actual)/2, 0, 0, I*np.conjugate(Om_1_actual)/2, I*np.conjugate(Om_2_actual), gamma23 + I*delta_2_actual, 0, 0],
            # Row 7
            [-I*Om_1_actual, 0, 0, -I*Om_2_actual/2, -I*Om_1_actual/2, 0, gamma13 - I*delta_1_actual, 0],
            # Row 8
            [-I*Om_2_actual/2, -I*Om_1_actual/2, 0, 0, -I*Om_2_actual, 0, 0, gamma23 - I*delta_2_actual]
        ], dtype=complex)

        # Construct the vector b
        b = np.array([
            Gamma31,
            0,
            I*np.conjugate(Om_1_actual)/2,
            0,
            Gamma32,
            I*np.conjugate(Om_2_actual)/2,
            -I*Om_1_actual/2,
            -I*Om_2_actual/2
        ], dtype=complex)

        # Solve the linear system A * v = b
        try:
            v = np.linalg.solve(A, b)
        except np.linalg.LinAlgError:
            # Handle singular matrix
            print("nan")
            return [np.nan] * 8  # Return an array of NaNs

        # Extract the solutions
        rho11 = np.real(v[0])
        rho12 = v[1]
        rho13 = v[2]
        rho21 = v[3]
        rho22 = np.real(v[4])
        rho23 = v[5]
        rho31 = v[6]
        rho32 = v[7]

        # Compute rho33
        rho33 = 1 - rho11 - rho22

        # Update the Rabi frequencies
        Om_2_list = Om_2_actual + z * (1j) * (k_0 / (epsilon_0 * hbar)) * N * rho32 * mu_23**2
        Om_1_list = Om_1_actual + z * (1j) * (k_0 / (epsilon_0 * hbar)) * N * rho31 * mu_13**2

        # Record Rabi frequencies at this z step
        Om_2_vs_z.append(Om_2_list.copy())
        Om_1_vs_z.append(Om_1_list.copy())
    
    # Convert lists to numpy arrays
    Om_2_vs_z = np.array(Om_2_vs_z)  # Shape: (nz, n_rabi)
    Om_1_vs_z = np.array(Om_1_vs_z)
    
    return Om_2_vs_z, Om_1_vs_z, z_array

def plot_OD(Om_1: list,delta_1: list, delta_2):
    
    Om_2_vs_z, Om_1_vs_z, z_array = calculate_OD_1(Om_1, delta_1, delta_2)
    
    # Extract real and imaginary parts
    Om_1_real = np.real(Om_1_vs_z)
    Om_1_imag = np.imag(Om_1_vs_z)
    Om_2_real = np.real(Om_2_vs_z)
    Om_2_imag = np.imag(Om_2_vs_z)

    # Plotting
    plt.figure(figsize=(12, 6))

    # Plot Omega_1
    plt.subplot(2, 1, 1)
    plt.plot(z_array, Om_1_real/(Om_1*Gamma3), label='Real part of Omega_1')
    plt.plot(z_array, Om_1_imag, label='Imaginary part of Omega_1')
    plt.xlabel('Position z (m)')
    plt.ylabel('Omega_1 (Hz)')
    plt.title('Omega_1 vs z')
    plt.legend()
    plt.grid(True)

    # Plot Omega_2
    plt.subplot(2, 1, 2)
    plt.plot(z_array, Om_2_real, label='Real part of Omega_2')
    plt.plot(z_array, Om_2_imag, label='Imaginary part of Omega_2')
    plt.xlabel('Position z (m)')
    plt.ylabel('Omega_2 (Hz)')
    plt.title('Omega_2 vs z')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()


# Create the button to start the simulation
run_button = widgets.Button(
    description="Run Simulation",
    button_style='success',  # 'success', 'info', 'warning', 'danger' or '' (default)
    tooltip='Click to run the simulation',
    icon='play'
)

# Function to be triggered when the button is clicked
def run_simulation(b):
    # Extract the current slider values
    Om_1 = 3
    delta_1 = 0
    delta_2 = 0
    
    # Call the plot_OD function with these values
    plot_OD(Om_1, delta_1, delta_2)

# Attach the function to the button
run_button.on_click(run_simulation)

# Display the sliders and the button
display(run_button)
# Out:
# 3.46e+16
# 3.46e+14
# Button(button_style='success', description='Run Simulation', icon='play', style=ButtonStyle(), tooltip='Click …
# Processing z step 2500/10000
# Processing z step 5000/10000
# Processing z step 7500/10000

# %% [markdown]
# ## HOT ATOM

# %%
import numpy as np
from scipy.optimize import fsolve

# Constants
epsilon_0 = 8.854e-12  # Vacuum permittivity (F/m)
hbar = 1.054e-34       # Reduced Planck's constant (J·s)
mu_13 = mu_23 = 2.5377e-29      # Dipole moment between states (|1> and |3>) and (|1> and |3>) (C·m)
lambda1 = 795e-9       # In m
c = 3e8

Gamma3 = 2 * np.pi * 6e6   # (Hz)
Gamma31 = 5/9 * Gamma3   # Decay from level 3 to level 1 (Hz)
Gamma32 = Gamma23 = 4/9 * Gamma3   # Decay from level 3 to level 2 (Hz)
Gamma12 = Gamma21 = 0.05 * Gamma3    # Decay rates between levels 1 and 2 (Hz)
gamma13 = (Gamma3 + Gamma12)/2  # Decoherence rate between levels 1 and 3 (Hz)
gamma23 = (Gamma3 + Gamma21)/2  # Decoherence rate between levels 2 and 3 (Hz)
gamma12 = (Gamma12 + Gamma21)/2     # Decoherence rate between ground states (Hz)

w_1 = 2 * np.pi * c / lambda1
k_0 = w_1 / c
L = 0.1        # Length in meters
z = 0.0001    # Step size in meters

k_b = 1.380649e-23     # Boltzmann constant (m^2 kg s^-2 K^-1)
m = 1.41e-25           # Mass of the particle (kg)
T = 0.00000001                # Temperature (K)
N = 3.5e16
#OD_0 = N*L*((2 * np.pi)**2 * np.abs(mu_13)**2) / (hbar * epsilon_0 * w_1 * lambda1) * np.sqrt(m * c**2 / (2 * np.pi * k_b * T)) 

OD_0 = 10
N1 = OD_0 * (1 / (((2 * np.pi)**2 * np.abs(mu_13)**2) / (hbar * epsilon_0 * w_1 * lambda1) * np.sqrt(m * c**2 / (2 * np.pi * k_b * T)) * L))

print("{:.2e}".format(N))
print("{:.2e}".format(N1))

# Thermal velocity standard deviation (Sigma)
sigma = np.sqrt(k_b * T / m)

# Maxwell-Boltzmann distribution function
def Maxwellian(V):
    return (1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-V**2 / (2 * sigma**2))

# Number of velocity points
nv = 51
v_values = np.zeros(nv)
dv = np.zeros(nv)
dv_min = 0.00003  # Minimum velocity increment

# Middle index (centered at zero velocity)
mid_index = nv // 2
v_values[mid_index] = 0
dv[mid_index] = dv_min * 2

# Area under Maxwellian at zero velocity
area = dv[mid_index] * Maxwellian(0)

# Compute positive velocities
for m in range(mid_index + 1, nv):
    v_end = v_values[m - 1] + dv[m - 1] / 2

    # Define the function to find the root of
    def func(V):
        return Maxwellian((V + v_end) / 2) * (V - v_end) - area

    # Initial guess for V
    V_guess = 1.5 * v_end if v_end != 0 else dv_min

    # Use fsolve to find V such that func(V) = 0
    V_solution = fsolve(func, V_guess)[0]

    # Update velocity and dv arrays
    v_values[m] = (V_solution + v_end) / 2
    dv[m] = V_solution - v_end

# Reflect to get negative velocities
v_values[:mid_index] = -np.flip(v_values[mid_index + 1:])
dv[:mid_index] = np.flip(dv[mid_index + 1:])

print(v_values)

# Maxwell-Boltzmann distribution weights
weights = Maxwellian(v_values)

# Verify that the total area under the curve approximates 1
total_area = np.sum(weights * dv)
print('Total area under Maxwellian:', total_area)


# Plotting with Data Points Marked
plt.figure(figsize=(12, 6))

# Plot the continuous Maxwellian distribution
plt.plot(v_values, weights, label='Maxwellian Distribution', color='blue')

# Mark each data point with a distinct marker
plt.scatter(v_values, weights, color='red', marker='o', s=50, label='Data Points')

plt.title('Maxwellian Distribution: Weights vs Velocity')
plt.xlabel('Velocity (m/s)')
plt.ylabel('Weight')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 3.50e+16
# 5.72e+10
# [-1.10832521e-02 -7.38883472e-03 -4.92588981e-03 -3.65408233e-03
#  -3.05184892e-03 -2.31293821e-03 -1.74707057e-03 -1.50860684e-03
#  -1.33787683e-03 -1.20043287e-03 -1.08319985e-03 -9.79613140e-04
#  -8.85855999e-04 -7.99490844e-04 -7.18853606e-04 -6.42749227e-04
#  -5.70283909e-04 -5.00766025e-04 -4.33644255e-04 -3.68467136e-04
#  -3.04855521e-04 -2.42483131e-04 -1.81062318e-04 -1.20333242e-04
#  -6.00553006e-05  0.00000000e+00  6.00553006e-05  1.20333242e-04
#   1.81062318e-04  2.42483131e-04  3.04855521e-04  3.68467136e-04
#   4.33644255e-04  5.00766025e-04  5.70283909e-04  6.42749227e-04
#   7.18853606e-04  7.99490844e-04  8.85855999e-04  9.79613140e-04
#   1.08319985e-03  1.20043287e-03  1.33787683e-03  1.50860684e-03
#   1.74707057e-03  2.31293821e-03  3.05184892e-03  3.65408233e-03
#   4.92588981e-03  7.38883472e-03  1.10832521e-02]
# Total area under Maxwellian: 0.9927308297261263
# /Users/MacPro2021/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_minpack_py.py:178: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# /Users/MacPro2021/Library/Python/3.9/lib/python/site-packages/scipy/optimize/_minpack_py.py:178: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last five Jacobian evaluations.
#   warnings.warn(msg, RuntimeWarning)

# %%
# Backend function to calculate OD based on user input
def calculate_OD_1(Om_1=1.0, delta_1=0.0, delta_2=0.0):
    n_rabi = 1
    Om_2_list = 7 * Gamma3 + 0j
    Om_1_list = Om_1 * Gamma3 + 0j
    
    nz = int(L / z)  # Number of z steps
    z_array = np.arange(nz) * z  # Array of z values
    
    # Initialize arrays to store Rabi frequencies at each z step
    Om_2_vs_z = []
    Om_1_vs_z = []

    for i in range(nz):
        #if i == nz/4 or i == nz/2 or i == 3*nz/4: 
        #print(f"Processing z step {i}/{nz}")
            
        # Initialize arrays to store rho31 and rho32
        rho31_values = []
        rho32_values = []
        
        for k in range(len(v_values)):                   
            
            Om_2_actual = Om_2_list      # Convert to actual Omega_2 in Hz
            Om_1_actual = Om_1_list      # Convert Om_1 to Hz
            
            delta_1_actual = delta_1 * Gamma3 + k_0 * v_values[k]
            delta_2_actual = delta_2 * Gamma3 + k_0 * v_values[k]

            # Define the imaginary unit
            I = 1j

            # Construct the matrix A
            A = np.array([
                # Row 1
                [Gamma31 + Gamma12, 0, I*Om_1_actual/2, 0, Gamma31 - Gamma21, 0, -I*np.conjugate(Om_1_actual)/2, 0],
                # Row 2
                [0, gamma12 - I*(delta_2_actual - delta_1_actual), I*Om_2_actual/2, 0, 0, 0, 0, -I*np.conjugate(Om_1_actual)/2],
                # Row 3
                [I*np.conjugate(Om_1_actual), I*np.conjugate(Om_2_actual)/2, gamma13 + I*delta_1_actual, 0, I*np.conjugate(Om_1_actual)/2, 0, 0, 0],
                # Row 4
                [0, 0, 0, gamma12 + I*(delta_2_actual - delta_1_actual), 0, I*Om_1_actual/2, -I*np.conjugate(Om_2_actual)/2, 0],
                # Row 5
                [Gamma32 - Gamma12, 0, 0, 0, Gamma32 + Gamma21, I*Om_2_actual/2, 0, -I*np.conjugate(Om_2_actual)/2],
                # Row 6
                [I*np.conjugate(Om_2_actual)/2, 0, 0, I*np.conjugate(Om_1_actual)/2, I*np.conjugate(Om_2_actual), gamma23 + I*delta_2_actual, 0, 0],
                # Row 7
                [-I*Om_1_actual, 0, 0, -I*Om_2_actual/2, -I*Om_1_actual/2, 0, gamma13 - I*delta_1_actual, 0],
                # Row 8
                [-I*Om_2_actual/2, -I*Om_1_actual/2, 0, 0, -I*Om_2_actual, 0, 0, gamma23 - I*delta_2_actual]
            ], dtype=complex)

            # Construct the vector b
            b = np.array([
                Gamma31,
                0,
                I*np.conjugate(Om_1_actual)/2,
                0,
                Gamma32,
                I*np.conjugate(Om_2_actual)/2,
                -I*Om_1_actual/2,
                -I*Om_2_actual/2
            ], dtype=complex)
            
            try:
                v = np.linalg.solve(A, b)
            except np.linalg.LinAlgError:
                # Handle singular matrix
                print(f"Singular matrix at z step {i}, velocity index {k}")
                rho31 = np.nan
                rho32 = np.nan
            else:
                # Extract the solutions
                rho11 = np.real(v[0])
                rho12 = v[1]
                rho13 = v[2]
                rho21 = v[3]
                rho22 = np.real(v[4])
                rho23 = v[5]
                rho31 = v[6]
                rho32 = v[7]

            # Compute rho33
            rho33 = 1 - rho11 - rho22

            # Store the populations
            rho31_values.append(rho31)
            rho32_values.append(rho32)  

        # Compute the weighted sums using dot product
        rho32_val = np.sum(rho32_values * weights * dv) / np.sum(weights * dv)
        rho31_val = np.sum(rho31_values * weights * dv) / np.sum(weights * dv)
                
        # Update the Rabi frequencies
        Om_2_list = Om_2_actual + z * (1j) * (k_0 / (epsilon_0 * hbar)) * N * rho32_val * mu_23**2
        Om_1_list = Om_1_actual + z * (1j) * (k_0 / (epsilon_0 * hbar)) * N * rho31_val * mu_13**2 
        
        #min_threshold = 1e-16  # Physically justified minimum value

        #if np.abs(Om_1_list) < min_threshold:
            #Om_1_list = min_threshold * np.exp(1j * np.angle(Om_1_list))
            #print(f"Om_1_list capped at step {i}")

        #if np.abs(Om_2_list) < min_threshold:
            #Om_2_list = min_threshold * np.exp(1j * np.angle(Om_2_list))
            #print(f"Om_2_list capped at step {i}")
        
        # Record Rabi frequencies at this z step
        Om_2_vs_z.append(Om_2_list.copy())
        Om_1_vs_z.append(Om_1_list.copy())

    # Convert lists to numpy arrays
    Om_2_vs_z = np.array(Om_2_vs_z)  # Shape: (nz, n_rabi)
    Om_1_vs_z = np.array(Om_1_vs_z)
    
    return Om_2_vs_z, Om_1_vs_z, z_array

def plot_OD(Om_1: list,delta_1: list, delta_2):
    
    Om_2_vs_z, Om_1_vs_z, z_array = calculate_OD_1(Om_1, delta_1, delta_2)
    
    # Extract real and imaginary parts
    Om_1_real = np.real(Om_1_vs_z)
    Om_1_imag = np.imag(Om_1_vs_z)
    Om_2_real = np.real(Om_2_vs_z)
    Om_2_imag = np.imag(Om_2_vs_z)

    # Plotting
    plt.figure(figsize=(12, 6))

    # Plot Omega_1
    plt.subplot(2, 1, 1)
    plt.plot(z_array, Om_1_real/(Gamma3*Om_1), label='Real part of Omega_1')
    plt.plot(z_array, Om_1_imag, label='Imaginary part of Omega_1')
    plt.xlabel('Position z (m)')
    plt.ylabel('Omega_1 (Hz)')
    plt.title('Omega_1 vs z')
    plt.legend()
    plt.grid(True)

    # Plot Omega_2
    plt.subplot(2, 1, 2)
    plt.plot(z_array, Om_2_real, label='Real part of Omega_2')
    plt.plot(z_array, Om_2_imag, label='Imaginary part of Omega_2')
    plt.xlabel('Position z (m)')
    plt.ylabel('Omega_2 (Hz)')
    plt.title('Omega_2 vs z')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()


# Create the button to start the simulation
run_button = widgets.Button(
    description="Run Simulation",
    button_style='success',  # 'success', 'info', 'warning', 'danger' or '' (default)
    tooltip='Click to run the simulation',
    icon='play'
)

# Function to be triggered when the button is clicked
def run_simulation(b):
    # Extract the current slider values
    Om_1 = 3
    delta_1 = 0
    delta_2 = 0
    
    # Call the plot_OD function with these values
    plot_OD(Om_1, delta_1, delta_2)

# Attach the function to the button
run_button.on_click(run_simulation)

# Display the sliders and the button
display(run_button)
# Out:
# Button(button_style='success', description='Run Simulation', icon='play', style=ButtonStyle(), tooltip='Click …

# %%
def compute_F1_F2(Om_1_input, Om_2_input, delta_1, delta_2):
    # Initialize arrays to store rho31 and rho32
    rho31_values = []
    rho32_values = []
    
    for k in range(len(v_values)):
        Om_1_actual = Om_1_input
        Om_2_actual = Om_2_input

        delta_1_actual = delta_1 * Gamma3 + k_0 * v_values[k] / (10**6)
        delta_2_actual = delta_2 * Gamma3 + k_0 * v_values[k] / (10**6)

        # Define the imaginary unit
        I = 1j

        # Construct the matrix A
        A = np.array([
            # Row 1
            [Gamma31 + Gamma12, 0, I*Om_1_actual/2, 0, Gamma31 - Gamma21, 0, -I*np.conjugate(Om_1_actual)/2, 0],
            # Row 2
            [0, gamma12 - I*(delta_2_actual - delta_1_actual), I*Om_2_actual/2, 0, 0, 0, 0, -I*np.conjugate(Om_1_actual)/2],
            # Row 3
            [I*np.conjugate(Om_1_actual), I*np.conjugate(Om_2_actual)/2, gamma13 + I*delta_1_actual, 0, I*np.conjugate(Om_1_actual)/2, 0, 0, 0],
            # Row 4
            [0, 0, 0, gamma12 + I*(delta_2_actual - delta_1_actual), 0, I*Om_1_actual/2, -I*np.conjugate(Om_2_actual)/2, 0],
            # Row 5
            [Gamma32 - Gamma12, 0, 0, 0, Gamma32 + Gamma21, I*Om_2_actual/2, 0, -I*np.conjugate(Om_2_actual)/2],
            # Row 6
            [I*np.conjugate(Om_2_actual)/2, 0, 0, I*np.conjugate(Om_1_actual)/2, I*np.conjugate(Om_2_actual), gamma23 + I*delta_2_actual, 0, 0],
            # Row 7
            [-I*Om_1_actual, 0, 0, -I*Om_2_actual/2, -I*Om_1_actual/2, 0, gamma13 - I*delta_1_actual, 0],
            # Row 8
            [-I*Om_2_actual/2, -I*Om_1_actual/2, 0, 0, -I*Om_2_actual, 0, 0, gamma23 - I*delta_2_actual]
        ], dtype=complex)

        # Construct the vector b
        b = np.array([
            Gamma31,
            0,
            I*np.conjugate(Om_1_actual)/2,
            0,
            Gamma32,
            I*np.conjugate(Om_2_actual)/2,
            -I*Om_1_actual/2,
            -I*Om_2_actual/2
        ], dtype=complex)

        # Solve the linear system A * v = b
        try:
            v = np.linalg.solve(A, b)
        except np.linalg.LinAlgError:
            # Handle singular matrix
            print("nan")
            return [np.nan] * 8  # Return an array of NaNs

        # Extract the solutions
        rho31 = v[6]
        rho32 = v[7]

        # Store the populations
        rho31_values.append(rho31)
        rho32_values.append(rho32)

    # Compute the weighted sums using dot product
    rho31_val = np.dot(rho31_values, weights)
    rho32_val = np.dot(rho32_values, weights)

    # Compute the derivatives
    F1 = (1j) * (k_0 / (epsilon_0 * hbar)) * N * rho31_val * mu_13**2
    F2 = (1j) * (k_0 / (epsilon_0 * hbar)) * N * rho32_val * mu_23**2

    return F1, F2

def calculate_OD_1(Om_1=1.0, delta_1=0.0, delta_2=0.0):
    Om_2_current = 4 * Gamma3 + 0j
    Om_1_current = Om_1 * Gamma3 + 0j
    
    nz = int(L / z)  # Number of z steps
    z_array = np.arange(nz) * z  # Array of z values
    
    # Initialize arrays to store Rabi frequencies at each z step
    Om_2_vs_z = []
    Om_1_vs_z = []

    for i in range(nz):
        print(f"Processing z step {i}/{nz}")
        
        # RK4 coefficients
        # k1
        F1_k1, F2_k1 = compute_F1_F2(Om_1_current, Om_2_current, delta_1, delta_2)
        k1_1 = F1_k1
        k1_2 = F2_k1

        # k2
        Om_1_k2 = Om_1_current + (z/2) * k1_1
        Om_2_k2 = Om_2_current + (z/2) * k1_2
        F1_k2, F2_k2 = compute_F1_F2(Om_1_k2, Om_2_k2, delta_1, delta_2)
        k2_1 = F1_k2
        k2_2 = F2_k2

        # k3
        Om_1_k3 = Om_1_current + (z/2) * k2_1
        Om_2_k3 = Om_2_current + (z/2) * k2_2
        F1_k3, F2_k3 = compute_F1_F2(Om_1_k3, Om_2_k3, delta_1, delta_2)
        k3_1 = F1_k3
        k3_2 = F2_k3

        # k4
        Om_1_k4 = Om_1_current + z * k3_1
        Om_2_k4 = Om_2_current + z * k3_2
        F1_k4, F2_k4 = compute_F1_F2(Om_1_k4, Om_2_k4, delta_1, delta_2)
        k4_1 = F1_k4
        k4_2 = F2_k4

        # Update the Rabi frequencies
        Om_1_next = Om_1_current + (z/6) * (k1_1 + 2*k2_1 + 2*k3_1 + k4_1)
        Om_2_next = Om_2_current + (z/6) * (k1_2 + 2*k2_2 + 2*k3_2 + k4_2)

        # Record Rabi frequencies at this z step
        Om_1_vs_z.append(Om_1_next)
        Om_2_vs_z.append(Om_2_next)

        # Prepare for next iteration
        Om_1_current = Om_1_next
        Om_2_current = Om_2_next

    # Convert lists to numpy arrays
    Om_1_vs_z = np.array(Om_1_vs_z)
    Om_2_vs_z = np.array(Om_2_vs_z)
    
    return Om_2_vs_z, Om_1_vs_z, z_array

def plot_OD(Om_1: list,delta_1: list, delta_2):
    
    Om_2_vs_z, Om_1_vs_z, z_array = calculate_OD_1(Om_1, delta_1, delta_2)
    
    # Extract real and imaginary parts
    Om_1_real = np.real(Om_1_vs_z)
    Om_1_imag = np.imag(Om_1_vs_z)
    Om_2_real = np.real(Om_2_vs_z)
    Om_2_imag = np.imag(Om_2_vs_z)

    # Plotting
    plt.figure(figsize=(12, 6))

    # Plot Omega_1
    plt.subplot(2, 1, 1)
    plt.plot(z_array, Om_1_real, label='Real part of Omega_1')
    plt.plot(z_array, Om_1_imag, label='Imaginary part of Omega_1')
    plt.xlabel('Position z (m)')
    plt.ylabel('Omega_1 (Hz)')
    plt.title('Omega_1 vs z')
    plt.legend()
    plt.grid(True)

    # Plot Omega_2
    plt.subplot(2, 1, 2)
    plt.plot(z_array, Om_2_real, label='Real part of Omega_2')
    plt.plot(z_array, Om_2_imag, label='Imaginary part of Omega_2')
    plt.xlabel('Position z (m)')
    plt.ylabel('Omega_2 (Hz)')
    plt.title('Omega_2 vs z')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()


# Create the button to start the simulation
run_button = widgets.Button(
    description="Run Simulation",
    button_style='success',  # 'success', 'info', 'warning', 'danger' or '' (default)
    tooltip='Click to run the simulation',
    icon='play'
)

# Function to be triggered when the button is clicked
def run_simulation(b):
    # Extract the current slider values
    Om_1 = 0.01
    delta_1 = 0
    delta_2 = 0
    
    # Call the plot_OD function with these values
    plot_OD(Om_1, delta_1, delta_2)

# Attach the function to the button
run_button.on_click(run_simulation)

# Display the sliders and the button
display(run_button)
# Out:
# Button(button_style='success', description='Run Simulation', icon='play', style=ButtonStyle(), tooltip='Click …
# Processing z step 0/1000
# Processing z step 1/1000
# Processing z step 2/1000
# Processing z step 3/1000
# Processing z step 4/1000
# Processing z step 5/1000
# Processing z step 6/1000
# Processing z step 7/1000
# Processing z step 8/1000
# Processing z step 9/1000
# Processing z step 10/1000
# Processing z step 11/1000
# Processing z step 12/1000
# Processing z step 13/1000
# Processing z step 14/1000
# Processing z step 15/1000
# Processing z step 16/1000
# Processing z step 17/1000
# Processing z step 18/1000
# Processing z step 19/1000
# Processing z step 20/1000
# Processing z step 21/1000
# Processing z step 22/1000
# Processing z step 23/1000
# Processing z step 24/1000
# Processing z step 25/1000
# Processing z step 26/1000
# Processing z step 27/1000
# Processing z step 28/1000
# Processing z step 29/1000
# Processing z step 30/1000
# Processing z step 31/1000
# Processing z step 32/1000
# Processing z step 33/1000
# Processing z step 34/1000
# Processing z step 35/1000
# Processing z step 36/1000
# Processing z step 37/1000
# Processing z step 38/1000
# Processing z step 39/1000
# Processing z step 40/1000
# Processing z step 41/1000
# Processing z step 42/1000
# Processing z step 43/1000
# Processing z step 44/1000
# Processing z step 45/1000
# Processing z step 46/1000
# Processing z step 47/1000
# Processing z step 48/1000
# Processing z step 49/1000
# Processing z step 50/1000
# Processing z step 51/1000
# Processing z step 52/1000
# Processing z step 53/1000
# Processing z step 54/1000
# Processing z step 55/1000
# Processing z step 56/1000
# Processing z step 57/1000
# Processing z step 58/1000
# Processing z step 59/1000
# Processing z step 60/1000
# Processing z step 61/1000
# Processing z step 62/1000
# Processing z step 63/1000
# Processing z step 64/1000
# Processing z step 65/1000
# Processing z step 66/1000
# Processing z step 67/1000
# Processing z step 68/1000
# Processing z step 69/1000
# Processing z step 70/1000
# Processing z step 71/1000
# Processing z step 72/1000
# Processing z step 73/1000
# Processing z step 74/1000
# Processing z step 75/1000
# Processing z step 76/1000
# Processing z step 77/1000
# Processing z step 78/1000
# Processing z step 79/1000
# Processing z step 80/1000
# Processing z step 81/1000
# Processing z step 82/1000
# Processing z step 83/1000
# Processing z step 84/1000
# Processing z step 85/1000
# Processing z step 86/1000
# Processing z step 87/1000
# Processing z step 88/1000
# Processing z step 89/1000
# Processing z step 90/1000
# Processing z step 91/1000
# Processing z step 92/1000
# Processing z step 93/1000
# Processing z step 94/1000
# Processing z step 95/1000
# Processing z step 96/1000
# Processing z step 97/1000
# Processing z step 98/1000
# Processing z step 99/1000
# Processing z step 100/1000
# Processing z step 101/1000
# Processing z step 102/1000
# Processing z step 103/1000
# Processing z step 104/1000
# Processing z step 105/1000
# Processing z step 106/1000
# Processing z step 107/1000
# Processing z step 108/1000
# Processing z step 109/1000
# Processing z step 110/1000
# Processing z step 111/1000
# Processing z step 112/1000
# Processing z step 113/1000
# Processing z step 114/1000
# Processing z step 115/1000
# Processing z step 116/1000
# Processing z step 117/1000
# Processing z step 118/1000
# Processing z step 119/1000
# Processing z step 120/1000
# Processing z step 121/1000
# Processing z step 122/1000
# Processing z step 123/1000
# Processing z step 124/1000
# Processing z step 125/1000
# Processing z step 126/1000
# Processing z step 127/1000
# Processing z step 128/1000
# Processing z step 129/1000
# Processing z step 130/1000
# Processing z step 131/1000
# Processing z step 132/1000
# Processing z step 133/1000
# Processing z step 134/1000
# Processing z step 135/1000
# Processing z step 136/1000
# Processing z step 137/1000
# Processing z step 138/1000
# Processing z step 139/1000
# Processing z step 140/1000
# Processing z step 141/1000
# Processing z step 142/1000
# Processing z step 143/1000
# Processing z step 144/1000
# Processing z step 145/1000
# Processing z step 146/1000
# Processing z step 147/1000
# Processing z step 148/1000
# Processing z step 149/1000
# Processing z step 150/1000
# Processing z step 151/1000
# Processing z step 152/1000
# Processing z step 153/1000
# Processing z step 154/1000
# Processing z step 155/1000
# Processing z step 156/1000
# Processing z step 157/1000
# Processing z step 158/1000
# Processing z step 159/1000
# Processing z step 160/1000
# Processing z step 161/1000
# Processing z step 162/1000
# Processing z step 163/1000
# Processing z step 164/1000
# Processing z step 165/1000
# Processing z step 166/1000
# Processing z step 167/1000
# Processing z step 168/1000
# Processing z step 169/1000
# Processing z step 170/1000
# Processing z step 171/1000
# Processing z step 172/1000
# Processing z step 173/1000
# Processing z step 174/1000
# Processing z step 175/1000
# Processing z step 176/1000
# Processing z step 177/1000
# Processing z step 178/1000
# Processing z step 179/1000
# Processing z step 180/1000
# Processing z step 181/1000
# Processing z step 182/1000
# Processing z step 183/1000
# Processing z step 184/1000
# Processing z step 185/1000
# Processing z step 186/1000
# Processing z step 187/1000
# Processing z step 188/1000
# Processing z step 189/1000
# Processing z step 190/1000
# Processing z step 191/1000
# Processing z step 192/1000
# Processing z step 193/1000
# Processing z step 194/1000
# Processing z step 195/1000
# Processing z step 196/1000
# Processing z step 197/1000
# Processing z step 198/1000
# Processing z step 199/1000
# Processing z step 200/1000
# Processing z step 201/1000
# Processing z step 202/1000
# Processing z step 203/1000
# Processing z step 204/1000
# Processing z step 205/1000
# Processing z step 206/1000
# Processing z step 207/1000
# Processing z step 208/1000
# Processing z step 209/1000
# Processing z step 210/1000
# Processing z step 211/1000
# Processing z step 212/1000
# Processing z step 213/1000
# Processing z step 214/1000
# Processing z step 215/1000
# Processing z step 216/1000
# Processing z step 217/1000
# Processing z step 218/1000
# Processing z step 219/1000
# Processing z step 220/1000
# Processing z step 221/1000
# Processing z step 222/1000
# Processing z step 223/1000
# Processing z step 224/1000
# Processing z step 225/1000
# Processing z step 226/1000
# Processing z step 227/1000
# Processing z step 228/1000
# Processing z step 229/1000
# Processing z step 230/1000
# Processing z step 231/1000
# Processing z step 232/1000
# Processing z step 233/1000
# Processing z step 234/1000
# Processing z step 235/1000
# Processing z step 236/1000
# Processing z step 237/1000
# Processing z step 238/1000
# Processing z step 239/1000
# Processing z step 240/1000
# Processing z step 241/1000
# Processing z step 242/1000
# Processing z step 243/1000
# Processing z step 244/1000
# Processing z step 245/1000
# Processing z step 246/1000
# Processing z step 247/1000
# Processing z step 248/1000
# Processing z step 249/1000
# Processing z step 250/1000
# Processing z step 251/1000
# Processing z step 252/1000
# Processing z step 253/1000
# Processing z step 254/1000
# Processing z step 255/1000
# Processing z step 256/1000
# Processing z step 257/1000
# Processing z step 258/1000
# Processing z step 259/1000
# Processing z step 260/1000
# Processing z step 261/1000
# Processing z step 262/1000
# Processing z step 263/1000
# Processing z step 264/1000
# Processing z step 265/1000
# Processing z step 266/1000
# Processing z step 267/1000
# Processing z step 268/1000
# Processing z step 269/1000
# Processing z step 270/1000
# Processing z step 271/1000
# Processing z step 272/1000
# Processing z step 273/1000
# Processing z step 274/1000
# Processing z step 275/1000
# Processing z step 276/1000
# Processing z step 277/1000
# Processing z step 278/1000
# Processing z step 279/1000
# Processing z step 280/1000
# Processing z step 281/1000
# Processing z step 282/1000
# Processing z step 283/1000
# Processing z step 284/1000
# Processing z step 285/1000
# Processing z step 286/1000
# Processing z step 287/1000
# Processing z step 288/1000
# Processing z step 289/1000
# Processing z step 290/1000
# Processing z step 291/1000
# Processing z step 292/1000
# Processing z step 293/1000
# Processing z step 294/1000
# Processing z step 295/1000
# Processing z step 296/1000
# Processing z step 297/1000
# Processing z step 298/1000
# Processing z step 299/1000
# Processing z step 300/1000
# Processing z step 301/1000
# Processing z step 302/1000
# Processing z step 303/1000
# Processing z step 304/1000
# Processing z step 305/1000
# Processing z step 306/1000
# Processing z step 307/1000
# Processing z step 308/1000
# Processing z step 309/1000
# Processing z step 310/1000
# Processing z step 311/1000
# Processing z step 312/1000
# Processing z step 313/1000
# Processing z step 314/1000
# Processing z step 315/1000
# Processing z step 316/1000
# Processing z step 317/1000
# Processing z step 318/1000
# Processing z step 319/1000
# Processing z step 320/1000
# Processing z step 321/1000
# Processing z step 322/1000
# Processing z step 323/1000
# Processing z step 324/1000
# Processing z step 325/1000
# Processing z step 326/1000
# Processing z step 327/1000
# Processing z step 328/1000
# Processing z step 329/1000
# Processing z step 330/1000
# Processing z step 331/1000
# Processing z step 332/1000
# Processing z step 333/1000
# Processing z step 334/1000
# Processing z step 335/1000
# Processing z step 336/1000
# Processing z step 337/1000
# Processing z step 338/1000
# Processing z step 339/1000
# Processing z step 340/1000
# Processing z step 341/1000
# Processing z step 342/1000
# Processing z step 343/1000
# Processing z step 344/1000
# Processing z step 345/1000
# Processing z step 346/1000
# Processing z step 347/1000
# Processing z step 348/1000
# Processing z step 349/1000
# Processing z step 350/1000
# Processing z step 351/1000
# Processing z step 352/1000
# Processing z step 353/1000
# Processing z step 354/1000
# Processing z step 355/1000
# Processing z step 356/1000
# Processing z step 357/1000
# Processing z step 358/1000
# Processing z step 359/1000
# Processing z step 360/1000
# Processing z step 361/1000
# Processing z step 362/1000
# Processing z step 363/1000
# Processing z step 364/1000
# Processing z step 365/1000
# Processing z step 366/1000
# Processing z step 367/1000
# Processing z step 368/1000
# Processing z step 369/1000
# Processing z step 370/1000
# Processing z step 371/1000
# Processing z step 372/1000
# Processing z step 373/1000
# Processing z step 374/1000
# Processing z step 375/1000
# Processing z step 376/1000
# Processing z step 377/1000
# Processing z step 378/1000
# Processing z step 379/1000
# Processing z step 380/1000
# Processing z step 381/1000
# Processing z step 382/1000
# Processing z step 383/1000
# Processing z step 384/1000
# Processing z step 385/1000
# Processing z step 386/1000
# Processing z step 387/1000
# Processing z step 388/1000
# Processing z step 389/1000
# Processing z step 390/1000
# Processing z step 391/1000
# Processing z step 392/1000
# Processing z step 393/1000
# Processing z step 394/1000
# Processing z step 395/1000
# Processing z step 396/1000
# Processing z step 397/1000
# Processing z step 398/1000
# Processing z step 399/1000
# Processing z step 400/1000
# Processing z step 401/1000
# Processing z step 402/1000
# Processing z step 403/1000
# Processing z step 404/1000
# Processing z step 405/1000
# Processing z step 406/1000
# Processing z step 407/1000
# Processing z step 408/1000
# Processing z step 409/1000
# Processing z step 410/1000
# Processing z step 411/1000
# Processing z step 412/1000
# Processing z step 413/1000
# Processing z step 414/1000
# Processing z step 415/1000
# Processing z step 416/1000
# Processing z step 417/1000
# Processing z step 418/1000
# Processing z step 419/1000
# Processing z step 420/1000
# Processing z step 421/1000
# Processing z step 422/1000
# Processing z step 423/1000
# Processing z step 424/1000
# Processing z step 425/1000
# Processing z step 426/1000
# Processing z step 427/1000
# Processing z step 428/1000
# Processing z step 429/1000
# Processing z step 430/1000
# Processing z step 431/1000
# Processing z step 432/1000
# Processing z step 433/1000
# Processing z step 434/1000
# Processing z step 435/1000
# Processing z step 436/1000
# Processing z step 437/1000
# Processing z step 438/1000
# Processing z step 439/1000
# Processing z step 440/1000
# Processing z step 441/1000
# Processing z step 442/1000
# Processing z step 443/1000
# Processing z step 444/1000
# Processing z step 445/1000
# Processing z step 446/1000
# Processing z step 447/1000
# Processing z step 448/1000
# Processing z step 449/1000
# Processing z step 450/1000
# Processing z step 451/1000
# Processing z step 452/1000
# Processing z step 453/1000
# Processing z step 454/1000
# Processing z step 455/1000
# Processing z step 456/1000
# Processing z step 457/1000
# Processing z step 458/1000
# Processing z step 459/1000
# Processing z step 460/1000
# Processing z step 461/1000
# Processing z step 462/1000
# Processing z step 463/1000
# Processing z step 464/1000
# Processing z step 465/1000
# Processing z step 466/1000
# Processing z step 467/1000
# Processing z step 468/1000
# Processing z step 469/1000
# Processing z step 470/1000
# Processing z step 471/1000
# Processing z step 472/1000
# Processing z step 473/1000
# Processing z step 474/1000
# Processing z step 475/1000
# Processing z step 476/1000
# Processing z step 477/1000
# Processing z step 478/1000
# Processing z step 479/1000
# Processing z step 480/1000
# Processing z step 481/1000
# Processing z step 482/1000
# Processing z step 483/1000
# Processing z step 484/1000
# Processing z step 485/1000
# Processing z step 486/1000
# Processing z step 487/1000
# Processing z step 488/1000
# Processing z step 489/1000
# Processing z step 490/1000
# Processing z step 491/1000
# Processing z step 492/1000
# Processing z step 493/1000
# Processing z step 494/1000
# Processing z step 495/1000
# Processing z step 496/1000
# Processing z step 497/1000
# Processing z step 498/1000
# Processing z step 499/1000
# Processing z step 500/1000
# Processing z step 501/1000
# Processing z step 502/1000
# Processing z step 503/1000
# Processing z step 504/1000
# Processing z step 505/1000
# Processing z step 506/1000
# Processing z step 507/1000
# Processing z step 508/1000
# Processing z step 509/1000
# Processing z step 510/1000
# Processing z step 511/1000
# Processing z step 512/1000
# Processing z step 513/1000
# Processing z step 514/1000
# Processing z step 515/1000
# Processing z step 516/1000
# Processing z step 517/1000
# Processing z step 518/1000
# Processing z step 519/1000
# Processing z step 520/1000
# Processing z step 521/1000
# Processing z step 522/1000
# Processing z step 523/1000
# Processing z step 524/1000
# Processing z step 525/1000
# Processing z step 526/1000
# Processing z step 527/1000
# Processing z step 528/1000
# Processing z step 529/1000
# Processing z step 530/1000
# Processing z step 531/1000
# Processing z step 532/1000
# Processing z step 533/1000
# Processing z step 534/1000
# Processing z step 535/1000
# Processing z step 536/1000
# Processing z step 537/1000
# Processing z step 538/1000
# Processing z step 539/1000
# Processing z step 540/1000
# Processing z step 541/1000
# Processing z step 542/1000
# Processing z step 543/1000
# Processing z step 544/1000
# Processing z step 545/1000
# Processing z step 546/1000
# Processing z step 547/1000
# Processing z step 548/1000
# Processing z step 549/1000
# Processing z step 550/1000
# Processing z step 551/1000
# Processing z step 552/1000
# Processing z step 553/1000
# Processing z step 554/1000
# Processing z step 555/1000
# Processing z step 556/1000
# Processing z step 557/1000
# Processing z step 558/1000
# Processing z step 559/1000
# Processing z step 560/1000
# Processing z step 561/1000
# Processing z step 562/1000
# Processing z step 563/1000
# Processing z step 564/1000
# Processing z step 565/1000
# Processing z step 566/1000
# Processing z step 567/1000
# Processing z step 568/1000
# Processing z step 569/1000
# Processing z step 570/1000
# Processing z step 571/1000
# Processing z step 572/1000
# Processing z step 573/1000
# Processing z step 574/1000
# Processing z step 575/1000
# Processing z step 576/1000
# Processing z step 577/1000
# Processing z step 578/1000
# Processing z step 579/1000
# Processing z step 580/1000
# Processing z step 581/1000
# Processing z step 582/1000
# Processing z step 583/1000
# Processing z step 584/1000
# Processing z step 585/1000
# Processing z step 586/1000
# Processing z step 587/1000
# Processing z step 588/1000
# Processing z step 589/1000
# Processing z step 590/1000
# Processing z step 591/1000
# Processing z step 592/1000
# Processing z step 593/1000
# Processing z step 594/1000
# Processing z step 595/1000
# Processing z step 596/1000
# Processing z step 597/1000
# Processing z step 598/1000
# Processing z step 599/1000
# Processing z step 600/1000
# Processing z step 601/1000
# Processing z step 602/1000
# Processing z step 603/1000
# Processing z step 604/1000
# Processing z step 605/1000
# Processing z step 606/1000
# Processing z step 607/1000
# Processing z step 608/1000
# Processing z step 609/1000
# Processing z step 610/1000
# Processing z step 611/1000
# Processing z step 612/1000
# Processing z step 613/1000
# Processing z step 614/1000
# Processing z step 615/1000
# Processing z step 616/1000
# Processing z step 617/1000
# Processing z step 618/1000
# Processing z step 619/1000
# Processing z step 620/1000
# Processing z step 621/1000
# Processing z step 622/1000
# Processing z step 623/1000
# Processing z step 624/1000
# Processing z step 625/1000
# Processing z step 626/1000
# Processing z step 627/1000
# Processing z step 628/1000
# Processing z step 629/1000
# Processing z step 630/1000
# Processing z step 631/1000
# Processing z step 632/1000
# Processing z step 633/1000
# Processing z step 634/1000
# Processing z step 635/1000
# Processing z step 636/1000
# Processing z step 637/1000
# Processing z step 638/1000
# Processing z step 639/1000
# Processing z step 640/1000
# Processing z step 641/1000
# Processing z step 642/1000
# Processing z step 643/1000
# Processing z step 644/1000
# Processing z step 645/1000
# Processing z step 646/1000
# Processing z step 647/1000
# Processing z step 648/1000
# Processing z step 649/1000
# Processing z step 650/1000
# Processing z step 651/1000
# Processing z step 652/1000
# Processing z step 653/1000
# Processing z step 654/1000
# Processing z step 655/1000
# Processing z step 656/1000
# Processing z step 657/1000
# Processing z step 658/1000
# Processing z step 659/1000
# Processing z step 660/1000
# Processing z step 661/1000
# Processing z step 662/1000
# Processing z step 663/1000
# Processing z step 664/1000
# Processing z step 665/1000
# Processing z step 666/1000
# Processing z step 667/1000
# Processing z step 668/1000
# Processing z step 669/1000
# Processing z step 670/1000
# Processing z step 671/1000
# Processing z step 672/1000
# Processing z step 673/1000
# Processing z step 674/1000
# Processing z step 675/1000
# Processing z step 676/1000
# Processing z step 677/1000
# Processing z step 678/1000
# Processing z step 679/1000
# Processing z step 680/1000
# Processing z step 681/1000
# Processing z step 682/1000
# Processing z step 683/1000
# Processing z step 684/1000
# Processing z step 685/1000
# Processing z step 686/1000
# Processing z step 687/1000
# Processing z step 688/1000
# Processing z step 689/1000
# Processing z step 690/1000
# Processing z step 691/1000
# Processing z step 692/1000
# Processing z step 693/1000
# Processing z step 694/1000
# Processing z step 695/1000
# Processing z step 696/1000
# Processing z step 697/1000
# Processing z step 698/1000
# Processing z step 699/1000
# Processing z step 700/1000
# Processing z step 701/1000
# Processing z step 702/1000
# Processing z step 703/1000
# Processing z step 704/1000
# Processing z step 705/1000
# Processing z step 706/1000
# Processing z step 707/1000
# Processing z step 708/1000
# Processing z step 709/1000
# Processing z step 710/1000
# Processing z step 711/1000
# Processing z step 712/1000
# Processing z step 713/1000
# Processing z step 714/1000
# Processing z step 715/1000
# Processing z step 716/1000
# Processing z step 717/1000
# Processing z step 718/1000
# Processing z step 719/1000
# Processing z step 720/1000
# Processing z step 721/1000
# Processing z step 722/1000
# Processing z step 723/1000
# Processing z step 724/1000
# Processing z step 725/1000
# Processing z step 726/1000
# Processing z step 727/1000
# Processing z step 728/1000
# Processing z step 729/1000
# Processing z step 730/1000
# Processing z step 731/1000
# Processing z step 732/1000
# Processing z step 733/1000
# Processing z step 734/1000
# Processing z step 735/1000
# Processing z step 736/1000
# Processing z step 737/1000
# Processing z step 738/1000
# Processing z step 739/1000
# Processing z step 740/1000
# Processing z step 741/1000
# Processing z step 742/1000
# Processing z step 743/1000
# Processing z step 744/1000
# Processing z step 745/1000
# Processing z step 746/1000
# Processing z step 747/1000
# Processing z step 748/1000
# Processing z step 749/1000
# Processing z step 750/1000
# Processing z step 751/1000
# Processing z step 752/1000
# Processing z step 753/1000
# Processing z step 754/1000
# Processing z step 755/1000
# Processing z step 756/1000
# Processing z step 757/1000
# Processing z step 758/1000
# Processing z step 759/1000
# Processing z step 760/1000
# Processing z step 761/1000
# Processing z step 762/1000
# Processing z step 763/1000
# Processing z step 764/1000
# Processing z step 765/1000
# Processing z step 766/1000
# Processing z step 767/1000
# Processing z step 768/1000
# Processing z step 769/1000
# Processing z step 770/1000
# Processing z step 771/1000
# Processing z step 772/1000
# Processing z step 773/1000
# Processing z step 774/1000
# Processing z step 775/1000
# Processing z step 776/1000
# Processing z step 777/1000
# Processing z step 778/1000
# Processing z step 779/1000
# Processing z step 780/1000
# Processing z step 781/1000
# Processing z step 782/1000
# Processing z step 783/1000
# Processing z step 784/1000
# Processing z step 785/1000
# Processing z step 786/1000
# Processing z step 787/1000
# Processing z step 788/1000
# Processing z step 789/1000
# Processing z step 790/1000
# Processing z step 791/1000
# Processing z step 792/1000
# Processing z step 793/1000
# Processing z step 794/1000
# Processing z step 795/1000
# Processing z step 796/1000
# Processing z step 797/1000
# Processing z step 798/1000
# Processing z step 799/1000
# Processing z step 800/1000
# Processing z step 801/1000
# Processing z step 802/1000
# Processing z step 803/1000
# Processing z step 804/1000
# Processing z step 805/1000
# Processing z step 806/1000
# Processing z step 807/1000
# Processing z step 808/1000
# Processing z step 809/1000
# Processing z step 810/1000
# Processing z step 811/1000
# Processing z step 812/1000
# Processing z step 813/1000
# Processing z step 814/1000
# Processing z step 815/1000
# Processing z step 816/1000
# Processing z step 817/1000
# Processing z step 818/1000
# Processing z step 819/1000
# Processing z step 820/1000
# Processing z step 821/1000
# Processing z step 822/1000
# Processing z step 823/1000
# Processing z step 824/1000
# Processing z step 825/1000
# Processing z step 826/1000
# Processing z step 827/1000
# Processing z step 828/1000
# Processing z step 829/1000
# Processing z step 830/1000
# Processing z step 831/1000
# Processing z step 832/1000
# Processing z step 833/1000
# Processing z step 834/1000
# Processing z step 835/1000
# Processing z step 836/1000
# Processing z step 837/1000
# Processing z step 838/1000
# Processing z step 839/1000
# Processing z step 840/1000
# Processing z step 841/1000
# Processing z step 842/1000
# Processing z step 843/1000
# Processing z step 844/1000
# Processing z step 845/1000
# Processing z step 846/1000
# Processing z step 847/1000
# Processing z step 848/1000
# Processing z step 849/1000
# Processing z step 850/1000
# Processing z step 851/1000
# Processing z step 852/1000
# Processing z step 853/1000
# Processing z step 854/1000
# Processing z step 855/1000
# Processing z step 856/1000
# Processing z step 857/1000
# Processing z step 858/1000
# Processing z step 859/1000
# Processing z step 860/1000
# Processing z step 861/1000
# Processing z step 862/1000
# Processing z step 863/1000
# Processing z step 864/1000
# Processing z step 865/1000
# Processing z step 866/1000
# Processing z step 867/1000
# Processing z step 868/1000
# Processing z step 869/1000
# Processing z step 870/1000
# Processing z step 871/1000
# Processing z step 872/1000
# Processing z step 873/1000
# Processing z step 874/1000
# Processing z step 875/1000
# Processing z step 876/1000
# Processing z step 877/1000
# Processing z step 878/1000
# Processing z step 879/1000
# Processing z step 880/1000
# Processing z step 881/1000
# Processing z step 882/1000
# Processing z step 883/1000
# Processing z step 884/1000
# Processing z step 885/1000
# Processing z step 886/1000
# Processing z step 887/1000
# Processing z step 888/1000
# Processing z step 889/1000
# Processing z step 890/1000
# Processing z step 891/1000
# Processing z step 892/1000
# Processing z step 893/1000
# Processing z step 894/1000
# Processing z step 895/1000
# Processing z step 896/1000
# Processing z step 897/1000
# Processing z step 898/1000
# Processing z step 899/1000
# Processing z step 900/1000
# Processing z step 901/1000
# Processing z step 902/1000
# Processing z step 903/1000
# Processing z step 904/1000
# Processing z step 905/1000
# Processing z step 906/1000
# Processing z step 907/1000
# Processing z step 908/1000
# Processing z step 909/1000
# Processing z step 910/1000
# Processing z step 911/1000
# Processing z step 912/1000
# Processing z step 913/1000
# Processing z step 914/1000
# Processing z step 915/1000
# Processing z step 916/1000
# Processing z step 917/1000
# Processing z step 918/1000
# Processing z step 919/1000
# Processing z step 920/1000
# Processing z step 921/1000
# Processing z step 922/1000
# Processing z step 923/1000
# Processing z step 924/1000
# Processing z step 925/1000
# Processing z step 926/1000
# Processing z step 927/1000
# Processing z step 928/1000
# Processing z step 929/1000
# Processing z step 930/1000
# Processing z step 931/1000
# Processing z step 932/1000
# Processing z step 933/1000
# Processing z step 934/1000
# Processing z step 935/1000
# Processing z step 936/1000
# Processing z step 937/1000
# Processing z step 938/1000
# Processing z step 939/1000
# Processing z step 940/1000
# Processing z step 941/1000
# Processing z step 942/1000
# Processing z step 943/1000
# Processing z step 944/1000
# Processing z step 945/1000
# Processing z step 946/1000
# Processing z step 947/1000
# Processing z step 948/1000
# Processing z step 949/1000
# Processing z step 950/1000
# Processing z step 951/1000
# Processing z step 952/1000
# Processing z step 953/1000
# Processing z step 954/1000
# Processing z step 955/1000
# Processing z step 956/1000
# Processing z step 957/1000
# Processing z step 958/1000
# Processing z step 959/1000
# Processing z step 960/1000
# Processing z step 961/1000
# Processing z step 962/1000
# Processing z step 963/1000
# Processing z step 964/1000
# Processing z step 965/1000
# Processing z step 966/1000
# Processing z step 967/1000
# Processing z step 968/1000
# Processing z step 969/1000
# Processing z step 970/1000
# Processing z step 971/1000
# Processing z step 972/1000
# Processing z step 973/1000
# Processing z step 974/1000
# Processing z step 975/1000
# Processing z step 976/1000
# Processing z step 977/1000
# Processing z step 978/1000
# Processing z step 979/1000
# Processing z step 980/1000
# Processing z step 981/1000
# Processing z step 982/1000
# Processing z step 983/1000
# Processing z step 984/1000
# Processing z step 985/1000
# Processing z step 986/1000
# Processing z step 987/1000
# Processing z step 988/1000
# Processing z step 989/1000
# Processing z step 990/1000
# Processing z step 991/1000
# Processing z step 992/1000
# Processing z step 993/1000
# Processing z step 994/1000
# Processing z step 995/1000
# Processing z step 996/1000
# Processing z step 997/1000
# Processing z step 998/1000
# Processing z step 999/1000
